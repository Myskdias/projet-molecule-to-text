# %%
from evaluation_validation_val import main

# %%
main()
# Out:
# [VAL EVAL] Device: cuda
# [VAL EVAL] Loading TRAIN graphs...
# Loading graphs from: data/train_graphs.pkl
# Loaded 31008 graphs
# [VAL EVAL] Loading VAL graphs...
# Loading graphs from: data/validation_graphs.pkl
# Loaded 1000 graphs
# [VAL EVAL] Loading CLIP model...
# [VAL EVAL] Building retrieval index...
# Construction de l'Index Vectoriel...
# Indexing: 100%|██████████| 969/969 [00:03<00:00, 299.16it/s]
# Index prêt. 31008 molécules indexées.
# [VAL EVAL] Running retrieval...
# Retrieval: 100%|██████████| 32/32 [00:00<00:00, 102.95it/s]
# [VAL EVAL] Collected 1000 predictions.
#
# [Evaluation] Computing BLEU-4...
# [Evaluation] BLEU-4: 0.3767
#
# [Evaluation] Computing BERTScore (RoBERTa-base)...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
from inference import main

main()
# Out:
# [INFER] Device: cuda
# [INFER] Loading TRAIN graphs...
# Loading graphs from: data/train_graphs.pkl
# Loaded 31008 graphs
# [INFER] Loading model...
# [INFER] Building retrieval index...
# Construction de l'Index Vectoriel...
# Indexing: 100%|██████████| 969/969 [00:03<00:00, 300.31it/s]
# Index prêt. 31008 molécules indexées.
# [INFER] Loading TEST graphs...
# Loading graphs from: data/test_graphs.pkl
# Loaded 1000 graphs
# [INFER] Running inference...
# Infer:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 from evaluation.inference import main
# ----> 3 main()
#
# File c:\Users\mathi\miniconda3\envs\ME\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("pred_v_res_annotated.csv")

# %%
df["error_type"].value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mathi\miniconda3\envs\ME\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'error_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...
