# %%
from editor.diff_maker import compute_edit_labels


retrieved = ["It","is", "the","conjugate","acid","of","X","."]
gold      = ["It","is", "me","the","conjugate","base","of","X","."]

labels = compute_edit_labels(retrieved, gold)
print(labels)
# Out:
# [0, 0, 0, 0, 2, 0, 0, 0]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "sentence-transformers/all-MiniLM-L6-v2"
)

# %%
text = "The molecule is a 1,2-diacyl-3-beta-D-galactosyl-sn-glycerol in which the acyl groups at positions 1 and 2 are specified as octanoyl."
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['the', 'molecule', 'is', 'a', '1', ',', '2', '-', 'dia', '##cy', '##l', '-', '3', '-', 'beta', '-', 'd', '-', 'gala', '##ct', '##os', '##yl', '-', 's', '##n', '-', 'g', '##ly', '##cer', '##ol', 'in', 'which', 'the', 'ac', '##yl', 'groups', 'at', 'positions', '1', 'and', '2', 'are', 'specified', 'as', 'oct', '##ano', '##yl', '.']

# %%
from editor.tokenizer import tokenizev
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from editor.tokenizer import tokenizev
#
# ImportError: cannot import name 'tokenizev' from 'editor.tokenizer' (c:\Users\mathi\Documents\MVA\altegrad\kaggle\projet-molecule-to-text\editor\tokenizer.py)

# %%
txt = "The molecule is a FAHFA obtained by formal condensation of the carboxy group of palmitic acid with the hydroxy group of 7-hydroxystearic acid. It has a role as an anti-inflammatory agent, a hypoglycemic agent and a human metabolite. It is a FAHFA and a long-chain fatty acid. It derives from a hexadecanoic acid and an octadecanoic acid. It is a conjugate acid of a 7-PAHSA(1-)."

# %%
tokenizev(txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tokenizev(txt)
#
# NameError: name 'tokenizev' is not defined
